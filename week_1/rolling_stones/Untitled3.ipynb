# %%
import csv
from collections import OrderedDict
import json
import matplotlib.pyplot as plt

#Opens databases

with open('data.csv') as f:
    # we are using DictReader because we want our information to be in dictionary format.
    reader = csv.DictReader(f)
    # some more code
    albums = []
    for album in reader:
        albums.append(OrderedDict(
            {'number': album['number'], 'year': album['year'], 'album': album['album'], 'artist': album['artist'],
             'genre': album['genre'], 'subgenre': album['subgenre']}))

def import_song_list():
    # open the text file in read
    text_file = open('top-500-songs.txt', 'r')
    # read each line of the text file
    # here is where you can print out the lines to your terminal and get an idea 
    # for how you might think about re-formatting the data
    lines = text_file.readlines()
    song_list = []
    for line in lines:
        clean_line = line.replace("\n", "")
        song_chart_keys = ["rank", "name", "artist", "year"]
        song_chart_values = clean_line.split("\t")
        song_list.append(dict(zip(song_chart_keys, song_chart_values))) 
    return song_list

file = open('track_data.json', 'r')
discography = json.load(file)
songs = import_song_list()

# %%
for disc in discography:
    print(disc['album'])
    print(disc['artist'])
    for i, track in enumerate(disc['tracks']):
        print([i, track])
# Out:
# Sgt. Pepper's Lonely Hearts Club Band
# The Beatles
# [0, "Sgt. Pepper's Lonely Hearts Club Band - Remix"]
# [1, 'With A Little Help From My Friends - Remix']
# [2, 'Lucy In The Sky With Diamonds - Remix']
# [3, 'Getting Better - Remix']
# [4, 'Fixing A Hole - Remix']
# [5, "She's Leaving Home - Remix"]
# [6, 'Being For The Benefit Of Mr. Kite! - Remix']
# [7, 'Within You Without You - Remix']
# [8, "When I'm Sixty-Four - Remix"]
# [9, 'Lovely Rita - Remix']
# [10, 'Good Morning Good Morning - Remix']
# [11, "Sgt. Pepper's Lonely Hearts Club Band (Reprise) - Remix"]
# [12, 'A Day In The Life - Remix']
# [13, "Sgt. Pepper's Lonely Hearts Club Band - Take 9 And Speech"]
# [14, 'With A Little Help From My Friends - Take 1 / False Start And Take 2 / Instrumental']
# [15, 'Lucy In The Sky With Diamonds - Take 1']
# [16, 'Getting Better - Take 1 / Instrumental And Speech At The End']
# [17, 'Fixing A Hole - Speech And Take 3']
# [18, "She's Leaving Home - Take 1 / Instrumental"]
# [19, 'Being For The Benefit Of Mr. Kite! - Take 4']
# [20, 'Within You Without You - Take 1 / Indian Instruments']
# [21, "When I'm Sixty-Four - Take 2"]
# [22, 'Lovely Rita - Speech And Take 9']
# [23, 'Good Morning Good Morning - Take 8']
# [24, "Sgt. Pepper's Lonely Hearts Club Band (Reprise) - Speech And Take 8"]
# [25, 'A Day In The Life - Take 1 With Hums']
# [26, 'Strawberry Fields Forever - Take 7']
# [27, 'Strawberry Fields Forever - Take 26']
# [28, 'Strawberry Fields Forever - Stereo Mix 2015']
# [29, 'Penny Lane - Take 6 / Instrumental']
# [30, 'Penny Lane - Stereo Mix 2017']
# Pet Sounds
# The Beach Boys
# [0, "Wouldn't It Be Nice - Digitally Remastered 96"]
# [1, 'You Still Believe In Me - Digitally Remastered 96']
# [2, "That's Not Me - 1996 Digital Remaster"]
# [3, "Don't Talk (Put Your Head On My Shoulder) - 1996 Digital Remaster"]
# [4, "I'm Waiting For The Day - Digitally Remastered 96"]
# [9, "What's Going On - Original Single Mix"]
# [10, 'Head Title aka Distant Lover - Demo Version']
# [11, 'Symphony - Demo Version']
# [12, 'I Love The Ground You Walk On - Instrumental']
# [13, "What's Going On - Mono Single Version"]
# [14, 'God Is Love - Mono Single Version']
# [15, 'Mercy Mercy Me (The Ecology) - Single Version (Mono)']
# [16, 'Sad Tomorrows - Mono Single Version']
# [17, 'Inner City Blues (Make Me Wanna Holler) - Mono Single Version']
# [18, 'Wholy Holy - Mono Single Version']
# [19, 'Checking Out (Double Clutch)']
# [20, 'Chained']
# [21, 'Country Stud']
# [22, 'Help The People']
# [23, 'Running From Love - Version 1']
# [24, 'Daybreak']
# [25, 'Doing My Thing']
# [26, '"T" Stands For Time']
# [27, 'Jesus Is Our Love Song']
# [28, 'Funky Nation']
# [29, 'Infinity']
# [30, 'Mandota']
# [31, "Struttin' The Blues"]
# [32, 'Running From Love - Version 2 (with strings)']
# [33, "I'm Going Home (Move)"]
# [34, "You're The Man - Pts. I & II - Original Mono Single Version"]
# [35, "You're The Man - Alternate Version 1"]
# [36, "You're The Man - Alternate Version 2"]
# [37, "What's Going On - Detroit Mix"]
# [38, "What's Happening Brother - Detroit Mix"]
# [39, "Flyin' High (In The Friendly Sky) - Detroit Mix"]
# [40, 'Save The Children - Detroit Mix']
# [41, 'God Is Love - Detroit Mix']
# [42, 'Mercy Mercy Me (The Ecology) - Detroit Mix']
# [43, 'Right On - Detroit Mix']
# [44, 'Wholy Holy - Detroit Mix']
# [45, 'Inner City Blues (Make Me Wanna Holler) - Detroit MIx']
# Exile on Main St.
# The Rolling Stones
# [0, 'Rocks Off']
# [1, 'Rip This Joint']
# [2, 'Shake Your Hips']
# [3, 'Casino Boogie']
# [4, 'Tumbling Dice']
# [5, 'Sweet Virginia']
# [6, 'Torn and Frayed']
# [7, 'Sweet Black Angel']
# [8, 'Loving Cup']
# [9, 'Happy']
# [10, 'Turd on the Run']
# [11, 'Ventilator Blues']
# [12, 'I Just Want to See His Face']
# [13, 'Let It Loose']
# [14, 'All Down the Line']
# [15, 'Stop Breaking Down']
# [16, 'Shine a Light']
# [17, 'Soul Survivor']
# London Calling
# The Clash
# [0, 'London Calling - Remastered']
# [1, 'Brand New Cadillac']
# [2, 'Jimmy Jazz']
# [3, 'Hateful']
# [4, "Rudie Can't Fail"]
# [5, 'Spanish Bombs']
# [6, 'The Right Profile']
# [7, 'Lost in the Supermarket']
# [8, 'Clampdown']
# [9, 'The Guns of Brixton']
# [10, "Wrong 'Em Boyo"]
# [11, 'Death or Glory']
# [12, 'Koka Kola']
# [13, 'The Card Cheat']
# [14, "Lover's Rock"]
# [15, 'Four Horsemen']
# [16, "I'm Not Down"]
# [17, 'Revolution Rock']
# [18, 'Train in Vain - Remastered']
# Blonde on Blonde
# Bob Dylan
# [0, 'Rainy Day Women #12 & 35']
# [1, 'Pledging My Time']
# [2, 'Visions of Johanna']
# [3, 'One of Us Must Know (Sooner or Later)']
# [4, 'I Want You']
# [5, 'Stuck Inside of Mobile with the Memphis Blues Again']
# [6, 'Leopard-Skin Pill-Box Hat']
# [0, 'So What']
# [1, 'Freddie Freeloader']
# [2, 'Blue in Green']
# [3, 'All Blues']
# [4, 'Flamenco Sketches']
# [5, 'Flamenco Sketches - Alternate Take']
# [6, 'Freddie Freeloader - Studio Sequence 1']
# [7, 'Freddie Freeloader - False Start']
# [8, 'Freddie Freeloader - Studio Sequence 2']
# [9, 'So What - Studio Sequence 1']
# [10, 'So What - Studio Sequence 2']
# [11, 'Blue in Green - Studio Sequence']
# [12, 'Flamenco Sketches - Studio Sequence 1']
# [13, 'Flamenco Sketches - Studio Sequence 2']
# [14, 'All Blues - Studio Sequence']
# [15, 'On Green Dolphin Street']
# [16, 'Fran-Dance']
# [17, 'Stella By Starlight']
# [18, 'Love For Sale']
# [19, 'Fran-Dance - alternate take']
# [20, 'So What - Live April 9th, 1960']
# The Velvet Underground & Nico
# The Velvet Underground
# [0, 'Sunday Morning']
# [1, "I'm Waiting For The Man - Album Version (Stereo)"]
# [2, 'Femme Fatale']
# [3, 'Venus In Furs']
# [4, 'Run Run Run']
# [5, "All Tomorrow's Parties"]
# [6, 'Heroin']
# [7, 'There She Goes Again']
# [8, "I'll Be Your Mirror"]
# [9, "The Black Angel's Death Song"]
# [10, 'European Son']
# [11, "All Tomorrow's Parties - Alternate Single Voice Version"]
# [12, 'European Son - Alternate Version']
# [13, 'Heroin - Alternate Version']
# [14, "All Tomorrow's Parties - Alternate Instrumental Mix"]
# [15, "I'll Be Your Mirror - Alternate Mix"]
# [16, 'Sunday Morning - Album Version (Mono)']
# [17, "I'm Waiting For The Man - Album Version (Mono)"]
# [18, 'Femme Fatale - Album Version (Mono)']
# [19, 'Venus In Furs - Album Version (Mono)']
# [20, 'Run Run Run - Album Version (Mono)']
# [21, "All Tomorrow's Parties - Album Version (Mono)"]
# [22, 'Heroin - Album Version (Mono)']
# [23, 'There She Goes Again - Album Version (Mono)']
# [24, "I'll Be Your Mirror - Album Version (Mono)"]
# [25, "Black Angel's Death Song - Album Version (Mono)"]
# [26, 'European Son - Album Version (Mono)']
# [27, "All Tomorrow's Parties - Mono Single"]
# [28, "I'll Be Your Mirror - Mono Single - Alternate Ending"]
# [29, 'Sunday Morning - Mono Single - Alternate Mix']
# [30, 'Femme Fatale - Mono Single']
# [31, 'The Fairest Of The Seasons']
# [32, 'These Days']
# [33, 'Little Sister']
# [34, 'Winter Song']
# [35, 'It Was A Pleasure Then']
# [36, 'Chelsea Girls']
# [37, "I'll Keep It With Mine"]
# [38, "Somewhere There's A Feather"]
# [39, 'Wrap Your Troubles In Dreams']
# [40, 'Eulogy To Lenny Bruce']
# [41, 'European Son - Scepter Studios Sessions - alternate version']
# [42, "Black Angel's Death Song - Scepter Studios Sessions - alternate mix"]
# [43, "All Tomorrow's Parties - Scepter Studios Sessions - alternate version"]
# [44, "I'll Be Your Mirror - Scepter Studios Sessions - alternate version"]
# [45, 'Heroin - Scepter Studios Sessions - alternate version']
# [46, 'Femme Fatale - Scepter Studios Sessions - alternate mix']
# [47, 'Venus In Furs - Scepter Studios Sessions - alternate version']
# [48, 'Waiting For The Man - Scepter Studios Sessions - alternate version']
# [49, 'Run Run Run - Scepter Studios Sessions - alternate mix']
# Abbey Road
# The Beatles
# [0, 'Come Together - Remastered']
# [1, 'Something - Remastered']
# [2, "Maxwell's Silver Hammer - Remastered"]
# [3, 'Oh! Darling - Remastered']
# [4, "Octopus's Garden - Remastered"]
# [5, "I Want You (She's So Heavy) - Remastered"]
# [6, 'Here Comes The Sun - Remastered']
# [7, 'Because - Remastered']
# [8, 'You Never Give Me Your Money - Remastered']
# [9, 'Sun King - Remastered']
# [10, 'Mean Mr Mustard - Remastered']
# [11, 'Polythene Pam - Remastered']
# [12, 'She Came In Through The Bathroom Window - Remastered']
# [13, 'Golden Slumbers - Remastered']
# [14, 'Carry That Weight - Remastered']
# [15, 'The End - Remastered']
# [16, 'Her Majesty - Remastered']
# Are You Experienced
# The Jimi Hendrix Experience
# [0, 'Purple Haze']
# [1, 'Manic Depression']
# [2, 'Hey Joe']
# [3, 'Love Or Confusion']
# [4, 'May This Be Love']
# [5, "I Don't Live Today"]
# [6, 'The Wind Cries Mary']
# [7, 'Fire']
# [8, 'Third Stone From The Sun']
# [9, 'Foxey Lady']
# [10, 'Are You Experienced?']
# [11, 'Stone Free']
# [12, '51st Anniversary']
# [13, 'Highway Chile']
# [14, 'Can You See Me']
# [15, 'Remember']
# [16, 'Red House']
# Blood on the Tracks
# Bob Dylan
# [0, 'Tangled up in Blue']
# [1, 'Simple Twist of Fate']
# [2, "You're a Big Girl Now"]
# [3, 'Idiot Wind']
# [4, "You're Gonna Make Me Lonesome When You Go"]
# [5, 'Meet Me in the Morning']
# [6, 'Lily, Rosemary and the Jack of Hearts']
# [7, 'If You See Her, Say Hello']
# [8, 'Shelter from the Storm']
# [9, 'Buckets of Rain']
# Nevermind
# Nirvana
# [0, 'Nevermind']
# Born to Run
# Bruce Springsteen
# [0, 'Thunder Road']
# [1, 'Tenth Avenue Freeze-Out']
# [2, 'Night']
# [3, 'Backstreets']
# [4, 'Born to Run']
# [5, "She's the One"]
# [6, 'Meeting Across the River']
# [7, 'Jungleland']
# Astral Weeks
# Van Morrison
# [0, 'Astral Weeks']
# [1, 'Beside You']
# [2, 'Sweet Thing']
# [3, 'Cyprus Avenue']
# [4, 'The Way Young Lovers Do']
# [5, 'Madame George']
# [6, 'Ballerina']
# [7, 'Slim Slow Slider']
# Thriller
# Michael Jackson
# [0, "Wanna Be Startin' Somethin'"]
# [1, 'Baby Be Mine']
# [2, 'The Girl Is Mine']
# [3, 'Thriller']
# [4, 'Beat It - Single Version']
# [5, 'Billie Jean']
# [6, 'Human Nature']
# [7, 'P.Y.T. (Pretty Young Thing)']
# [8, 'The Lady in My Life']
# [9, 'Vincent Price Excerpt From "Thriller" Voice-Over Session - Thriller 25th Anniversary Voice-Over Session']
# [10, 'The Girl Is Mine 2008 with will.i.am - Thriller 25th Anniversary Remix']
# [11, 'P.Y.T. (Pretty Young Thing) 2008 with will.i.am - Thriller 25th Anniversary Remix feat. willi.i.am']
# [12, "Wanna Be Startin' Somethin' 2008 with Akon - Thriller 25th Anniversary Remix"]
# [13, 'Beat It 2008 - Thriller 25th Anniversary Remix feat. Fergie']
# [14, 'Billie Jean 2008 Kanye West Mix - Thriller 25th Anniversary Remix']
# [15, 'For All Time']
# [16, 'Voice-Over Intro Quincy Jones Interview #1 / Quincy Jones Interview #1']
# [17, 'Someone in the Dark']
# [18, 'Voice-Over Intro Quincy Jones Interview #2/Quincy Jones Interview #2 / Voice-Over Intro Billie Jean (Demo)']
# [19, 'Billie Jean (Home Demo from 1981)']
# [20, 'Quincy Jones Interview #3']
# [21, 'Voice-Over Intro Rod Temperton Interview #1 / Rod Temperton Interview #1']
# [22, 'Quincy Jones Interview #4']
# [23, 'Voice-Over Intro / Voice-Over Session from Thriller']
# [24, 'Voice-Over Intro Rod Temperton Interview #2 / Rod Temperton Interview #2']
# [25, 'Quincy Jones Interview #5']
# [26, 'Carousel']
# [27, 'Voice-Over Intro Quincy Jones Interview #6 / Quincy Jones Interview #6']
# [28, 'Billie Jean - Underground Mix']
# [29, 'Thriller - Instrumental']
# The Great Twenty Eight
# Chuck Berry
# [0, 'Maybellene - Single Version']
# [1, 'Thirty Days (To Come Back Home) - Single Version']
# [2, "You Can't Catch Me - Single Version"]
# [3, 'Too Much Monkey Business - Single Version']
# [4, 'Brown Eyed Handsome Man - Single Version']
# [5, 'Roll Over Beethoven - Single Version']
# [6, 'Havana Moon - Single Version']
# [7, 'School Day (Ring Ring Goes The Bell) - Single Version']
# [8, 'Rock And Roll Music']
# [9, 'Oh Baby Doll - 1957 Single Version']
# [10, "Reelin' And Rockin' - Single Version"]
# [11, 'Sweet Little Sixteen - Original Demo']
# [12, 'Johnny B. Goode - Single Version']
# [13, 'Around And Around - Single Version']
# [14, 'Carol - Single Version']
# [15, 'Beautiful Delilah - Single Version']
# [16, 'Memphis, Tennessee - Single Version']
# [17, "Sweet Little Rock 'N' Roller - Single Version"]
# [18, 'Little Queenie - Single Version']
# [19, 'Almost Grown - Single Version']
# [20, 'Back In The U.S.A. - Single Version']
# [21, 'Let It Rock - Single Version']
# [22, 'Bye Bye Johnny - Single Version']
# [23, "I'm Talking About You - Single Version"]
# [24, 'Come On - Single Version (Mono)']
# [25, 'Nadine - Single Version']
# [26, 'No Particular Place To Go - Single Version']
# [27, 'I Want To Be Your Driver']
# The Complete Recordings
# Robert Johnson
# [0, 'Pennies From Heaven']
# [1, 'Please Be Kind']
# [2, '(Love Is) The Tender Trap']
# [3, 'Looking At The World Through Rose Colored Glasses']
# [4, 'My Kind Of Girl']
# [5, 'I Only Have Eyes For You']
# [6, 'Nice Work If You Can Get It']
# [7, "Learnin' The Blues"]
# [8, "I'm Gonna Sit Right Down (And Write Myself A Letter)"]
# [9, "I Won't Dance"]
# [10, 'Fly Me To The Moon']
# [11, 'I Wish You Love']
# [12, 'I Believe In You']
# [13, 'More (Theme From Mondo Cane)']
# [14, "I Can't Stop Loving You"]
# [15, 'Hello, Dolly!']
# [16, 'I Wanna Be Around']
# [17, 'The Best Is Yet To Come']
# [18, 'The Good Life']
# [19, 'Wives And Lovers']
# John Lennon/Plastic Ono Band
# John Lennon / Plastic Ono Band
# [42, 'Brushes (Never Going Back Again) [Sessions, Roughs & Outtakes] - 2004 Remastered Edition']
# [43, "Don't Stop (Sessions, Roughs & Outtakes) - 2004 Remastered Edition"]
# [44, 'Go Your Own Way (Sessions, Roughs & Outtakes) - 2004 Remastered Edition']
# [45, 'Songbird (Sessions, Roughs & Outtakes) - 2004 Remastered Edition']
# [46, 'Silver Springs (Sessions, Roughs & Outtakes) - 2004 Remastered Edition']
# [47, 'You Make Loving Fun (Sessions, Roughs & Outtakes) - 2004 Remastered Edition']
# [48, 'Gold Dust Woman #1 (Sessions, Roughs & Outtakes) - 2004 Remastered Edition']
# [49, 'Oh Daddy (Sessions, Roughs & Outtakes) - 2004 Remastered Edition']
# The Joshua Tree
# U2
# [0, 'Where The Streets Have No Name']
# [1, "I Still Haven't Found What I'm Looking For"]
# [2, 'With Or Without You']
# [3, 'Bullet The Blue Sky']
# [4, 'Running To Stand Still']
# [5, 'Red Hill Mining Town']
# [6, "In God's Country"]
# [7, 'Trip Through Your Wires']
# [8, 'One Tree Hill']
# [9, 'Exit']
# [10, 'Mothers Of The Disappeared']
# [11, 'Where The Streets Have No Name - Live']
# [12, 'I Will Follow - Live']
# [13, 'Trip Through Your Wires - Live']
# [14, 'Medley: I Still Haven’t Found What I’m Looking For / Exodus - Live']
# [15, 'MLK - Live']
# [16, 'Bullet The Blue Sky - Live']
# [17, 'Running To Stand Still - Live']
# [18, 'In God’s Country - Live']
# [19, 'Sunday Bloody Sunday - Live']
# [20, 'Medley: Exit / Gloria - Live']
# [21, 'October - Live']
# [22, 'New Year’s Day - Live']
# [23, 'Pride (In The Name Of Love) - Live']
# [24, 'With Or Without You - Live']
# [25, 'Party Girl - Live']
# [26, 'I Still Haven’t Found What I’m Looking For - Live / Choir Version']
# [27, '“40” - Live']
# [28, 'One Tree Hill - St Francis Hotel Remix']
# [29, 'Bullet The Blue Sky - Jacknife Lee Remix']
# [30, 'Running To Stand Still - Daniel Lanois Remix']
# [31, 'Red Hill Mining Town - Steve Lillywhite 2017 Mix']
# [32, 'With Or Without You - Daniel Lanois Remix']
# [33, 'Where The Streets Have No Name - Flood Remix']
# [34, 'Luminous Times (Hold On To Love)']
# [35, 'Walk To The Water']
# [36, 'Spanish Eyes']
# [37, 'Deep In The Heart']
# [38, 'Silver And Gold']
# [39, 'Sweetest Thing']
# [40, 'Race Against Time']
# [41, "I Still Haven't Found What I'm Looking For - Lillywhite Alternative Mix ’87"]
# [42, 'One Tree Hill Reprise - Brian Eno 2017 Mix']
# [43, 'Silver And Gold']
# [44, 'Beautiful Ghost / Introduction To Songs Of Experience']
# [45, 'Wave Of Sorrow (Birdland)']
# [46, 'Desert Of Our Love']
# [47, 'Rise Up']
# [48, 'Drunk Chicken / America']
# Who's Next
# The Who
# [0, "Baba O'Riley - Remix"]
# [1, 'Bargain']
# [2, "Love Ain't For Keeping"]
# [3, 'My Wife - Original Album Version']
# [4, 'The Song Is Over']
# [5, 'Getting In Tune']
# [6, 'Going Mobile - Original Album Version']
# [7, 'Behind Blue Eyes']
# [8, "Won't Get Fooled Again - Remix"]
# [9, 'Pure And Easy']
# [10, "Baby Don't You Do It"]
# [11, 'Naked Eye']
# [12, 'Water - The Young Vic Theatre Live Version']
# [13, 'Too Much Of Anything']
# [14, "I Don't Even Know Myself"]
# [15, 'Behind Blue Eyes - Alternate Studio Version']
# Led Zeppelin
# Led Zeppelin
# [0, 'Black Dog']
# [1, 'Rock And Roll']
# [2, 'The Battle Of Evermore']
# [3, 'Stairway To Heaven']
# [4, 'Misty Mountain Hop']
# [5, 'Four Sticks']
# [6, 'Going To California']
# [7, 'When The Levee Breaks']
# [8, 'Black Dog - Basic Track With Guitar Overdubs']
# [9, 'Rock And Roll - Alternate Mix']
# [10, 'The Battle Of Evermore - Mandolin / Guitar Mix From Headley Grange']
# [11, 'Stairway To Heaven - Sunset Sound Mix']
# [12, 'Misty Mountain Hop - Alternate Mix']
# [13, 'Four Sticks - Alternate Mix']
# [14, 'Going To California - Mandolin / Guitar Mix']
# [15, 'When The Levee Breaks - Alternate UK Mix In Progress']
# Blue
# Joni Mitchell
# [0, 'WILD']
# [1, 'BITE']
# [2, 'FOOLS']
# [3, 'EASE']
# [4, 'THE QUIET']
# [5, 'DKLA']
# [6, 'TALK ME DOWN']
# [7, 'COOL']
# [8, 'HEAVEN']
# [9, 'YOUTH']
# [10, 'LOST BOY']
# [11, 'for him.']
# [12, 'SUBURBIA']
# [13, 'TOO GOOD']
# [14, 'BLUE']
# [15, 'WILD - XXYYXX Remix']
# Bringing It All Back Home
# Bob Dylan
# [0, 'Subterranean Homesick Blues']
# [1, 'She Belongs to Me']
# [2, "Maggie's Farm"]
# [3, 'Love Minus Zero']
# [4, 'Outlaw Blues']
# [5, 'On the Road Again']
# [6, "Bob Dylan's 115th Dream"]
# [7, 'Mr. Tambourine Man']
# [8, 'Gates of Eden']
# [9, "It's Alright, Ma (I'm Only Bleeding)"]
# [10, "It's All over Now, Baby Blue"]
# Let It Bleed
# The Rolling Stones
# [0, 'Gimme Shelter']
# [1, 'Love In Vain']
# [2, 'Country Honk']
# [3, 'Live With Me']
# [4, 'Let It Bleed']
# [5, 'Midnight Rambler']
# [6, 'You Got The Silver']
# [7, 'Monkey Man']
# [8, "You Can't Always Get What You Want"]
# Ramones
# Ramones
# [0, 'Blitzkrieg Bop - 2016 Remastered Version']
# [1, 'Beat On The Brat - 2016 Remastered']
# [2, 'Judy Is A Punk']
# [3, 'I Wanna Be Your Boyfriend']
# [4, 'Chain Saw']
# [5, 'Now I Wanna Sniff Some Glue']
# [6, "I Don't Wanna Go Down To The Basement"]
# [7, 'Loudmouth']
# [8, 'Havana Affair']
# [9, 'Listen To My Heart']
# [10, '53rd & 3rd']
# [11, "Let's Dance"]
# [12, "I Don't Wanna Walk Around With You"]
# [13, 'Today Your Love, Tomorrow The World']
# [14, 'Blitzkrieg Bop - 40th Anniversary Mono Mix']
# [15, 'Beat On The Brat - 40th Anniversary Mono Mix']
# [16, 'Judy Is A Punk - 40th Anniversary Mono Mix']
# [17, 'I Wanna Be Your Boyfriend - 40th Anniversary Mono Mix']
# [18, 'Chain Saw - 40th Anniversary Mono Mix']
# [19, 'Now I Wanna Sniff Some Glue - 40th Anniversary Mono Mix']
# [20, "I Don't Wanna Go Down To The Basement - 40th Anniversary Mono Mix"]
# [21, 'Loudmouth - 40th Anniversary Mono Mix']
# [22, 'Havana Affair - 40th Anniversary Mono Mix']
# [23, 'Listen To My Heart - 40th Anniversary Mono Mix']
# [24, '53rd & 3rd - 40th Anniversary Mono Mix']
# [25, "Let's Dance - 40th Anniversary Mono Mix"]
# [26, "I Don't Wanna Walk Around With You - 40th Anniversary Mono Mix"]
# [27, 'Today Your Love, Tomorrow The World - 40th Anniversary Mono Mix']
# [28, 'Blitzkrieg Bop (Original Stereo) - Single Version']
# [29, 'Blitzkrieg Bop (Original Mono) - Single Version']
# [30, 'I Wanna Be Your Boyfriend (Original Stereo) - Single Version']
# [31, 'I Wanna Be Your Boyfriend (Original Mono) - Single Version']
# [32, 'Today Your Love, Tomorrow The World - Uncensored Vocals']
# [33, "I Don't Care (Demo) - 2016 Remastered"]
# [34, '53rd & 3rd - Demo']
# [35, 'Loudmouth - Demo Version']
# [36, 'Chain Saw - Demo']
# [37, 'You Should Have Never Opened That Door (Demo)']
# [38, 'I Wanna Be Your Boyfriend (Demo)']
# [39, "I Can't Be (Demo)"]
# [40, 'Today Your Love, Tomorrow The World (Demo)']
# [41, "I Don't Wanna Walk Around With You (Demo)"]
# [42, 'Now I Wanna Sniff Some Glue (Demo) - 2016 Remastered']
# [43, "I Don't Wanna Be Learned / I Don't Wanna Be Tamed (Demo)"]
# [44, "You're Gonna Kill That Girl (Demo)"]
# [45, "What's Your Name (Demo)"]
# [46, 'Loudmouth (Set 1) - Live at the Roxy, Hollywood, CA (8/12/76)']
# [47, 'Beat On The Brat (Set 1) - Live at the Roxy, Hollywood, CA (8/12/76']
# [48, 'Blitzkrieg Bop (Set 1) - Live at the Roxy, Hollywood, CA (8/12/76)']
# [49, 'I Remember You (Set 1) - Live at the Roxy, Hollywood, CA (8/12/76)']
# Music From Big Pink
# The Band
# [0, 'Tears Of Rage - 2000 Digital Remaster']
# [1, 'To Kingdom Come - 2000 Digital Remaster']
# [2, 'In A Station - 2000 Digital Remaster']
# [3, 'Caledonia Mission - 2000 Digital Remaster']
# [4, 'The Weight - 2000 - Remaster']
# [5, 'We Can Talk - 2000 Digital Remaster']
# [6, 'Long Black Veil - 2000 Digital Remaster']
# [7, 'Chest Fever - 2000 Digital Remaster']
# [8, 'Lonesome Suzie - 2000 Digital Remaster']
# [9, "This Wheel's On Fire - 2000 Digital Remaster"]
# [10, 'I Shall Be Released - 2000 Digital Remaster']
# [11, 'Yazoo Street Scandal - 2000 Digital Remaster']
# [12, 'Tears Of Rage - 2000 Digital Remaster']
# [13, "Katie's Been Gone - 2000 Digital Remaster"]
# [14, 'If I Lose - 2000 Digital Remaster']
# [15, 'Long Distance Operator - 2000 Digital Remaster']
# [16, 'Lonesome Suzie - 2000 Digital Remaster']
# [17, 'Orange Juice Blues (Blues For Breakfast)(Outtake Demo) - 2000 Digital Remaster']
# [18, 'Key To The Highway - 2000 Digital Remaster']
# [19, 'Ferdinand The Imposter - 2000 Digital Remaster']
# [12, "There's A Place - Remastered"]
# [13, 'Twist And Shout - Remastered']
# Forever Changes
# Love
# [0, 'Alone Again Or - 2015 Remastered Version']
# [1, 'A House Is Not A Motel - 2015 Remastered Version']
# [2, 'Andmoreagain - 2015 Remastered Version']
# [3, 'The Daily Planet - 2015 Remastered Version']
# [4, 'Old Man - 2015 Remastered Version']
# [5, 'The Red Telephone - 2015 Remastered Version']
# [6, 'Maybe The People Would Be The Times Or Between Clark And Hilldale - 2015 Remastered Version']
# [7, 'Live And Let Live - 2015 Remastered Version']
# [8, 'The Good Humor Man He Sees Everything Like This - 2015 Remastered Version']
# [9, 'Bummer In The Summer - 2015 Remastered Version']
# [10, 'You Set The Scene - 2015 Remastered Version']
# Never Mind the Bollocks Here's the Sex Pistols
# Sex Pistols
# [0, 'Holidays In The Sun']
# [1, 'Bodies']
# [2, 'No Feelings']
# [3, 'Liar']
# [4, 'Problems']
# [5, 'God Save The Queen']
# [6, 'Seventeen']
# [7, 'Anarchy In The U.K.']
# [8, 'Sub-Mission']
# [9, 'Pretty Vacant']
# [10, 'New York']
# [11, 'EMI']
# The Doors
# The Doors
# [0, 'Break On Through (To The Other Side)']
# [1, 'Soul Kitchen']
# [2, 'The Crystal Ship']
# [3, 'Twentieth Century Fox']
# [4, 'Alabama Song (Whisky Bar)']
# [5, 'Light My Fire']
# [6, 'Back Door Man']
# [7, 'I Looked At You']
# [8, 'End Of The Night']
# [9, 'Take It As It Comes']
# [10, 'The End']
# The Dark Side of the Moon
# Pink Floyd
# [0, 'Speak to Me']
# [1, 'Breathe (In the Air)']
# [2, 'On the Run']
# [3, 'Time']
# [4, 'The Great Gig in the Sky']
# [5, 'Money']
# [6, 'Us and Them']
# [7, 'Any Colour You Like']
# [8, 'Brain Damage']
# [9, 'Eclipse']
# Horses
# Patti Smith
# [0, 'Horses (with PnB Rock, Kodak Black & A Boogie Wit da Hoodie)']
# The Brown Album
# The Band
# [0, 'Westside']
# [1, "Nothin' Like Me"]
# [2, 'Ayo']
# [3, 'Girl You Loud']
# [4, 'Remember Me']
# [5, 'I Bet']
# [6, 'D.G.I.F.U.']
# [7, 'Better']
# [8, 'Lights Out']
# [9, 'Real One']
# [10, 'Bitches N Marijuana']
# [11, "She Goin' Up"]
# [12, 'Wrong In The Right Way']
# [13, "Bunkin'"]
# [14, "It's Yo Shit"]
# [15, 'Banjo']
# The Best of Bob Marley and The Wailers
# Bob Marley & The Wailers
# [0, 'Buffalo Soldier (in the style of Bob Marley & The Wailers) (Karaoke Version)']
# [1, 'Buffalo Soldier (in the style of Bob Marley & The Wailers) (Demonstration Version - includes lead singer)']
# [2, 'Redemption Song (Acoustic Version) (in the style of Bob Marley & The Wailers) (Karaoke Version)']
# [3, 'Redemption Song (Acoustic Version) (in the style of Bob Marley & The Wailers) (Demonstration Version - includes lead singer)']
# [4, 'Could You Be Loved (in the style of Bob Marley & The Wailers) (Karaoke Version)']
# [5, 'Could You Be Loved (in the style of Bob Marley & The Wailers) (Demonstration Version - includes lead singer)']
# [6, 'I Shot The Sheriff (in the style of Bob Marley / The Wailers) (Karaoke Version)']
# [16, 'Ready Teddy - Take 1']
# [17, 'Ready Teddy - Takes 2 & 3']
# [18, 'Baby - Demo']
# [19, 'Baby - Take 1']
# [20, 'Slippin’ And Slidin’ - Demo']
# [21, 'Slippin’ And Slidin’ - Piano & Drums Demo']
# [22, 'Long Tall Sally - Take 1']
# [23, 'Long Tall Sally - Take 6']
# [24, 'Miss Ann - Demo']
# [25, 'Miss Ann - Take 1']
# [26, 'Miss Ann - Take 6']
# [27, 'Oh Why? - Takes 3 & 4']
# [28, 'Oh Why? - Take 9']
# [29, 'Rip It Up - Take 1']
# [30, 'Rip It Up - Take 3']
# [31, 'Rip It Up - Take 4']
# [32, 'Rip It Up - Take 6']
# [33, 'She’s Got It - Alternate Version']
# Bridge Over Troubled Water
# Simon & Garfunkel
# [0, 'Bridge Over Troubled Water']
# [1, 'El Condor Pasa (If I Could)']
# [2, 'Cecilia']
# [3, 'Keep the Customer Satisfied']
# [4, 'So Long, Frank Lloyd Wright']
# [5, 'The Boxer']
# [6, 'Baby Driver']
# [7, 'The Only Living Boy in New York']
# [8, "Why Don't You Write Me"]
# [9, 'Bye Bye Love - Live at Memorial Auditorium, Burlington, VT - October 1968']
# [10, 'Song for the Asking']
# Greatest Hits
# Al Green
# [0, 'Keep Ya Head Up']
# [1, '2 Of Amerikaz Most Wanted']
# [2, 'Temptations']
# [3, 'God Bless The Dead - 1998 Greatest Hits']
# [4, 'Hail Mary']
# [5, 'Me Against The World']
# [6, 'How Do U Want It']
# [7, 'So Many Tears']
# [8, 'Unconditional Love']
# [9, 'Trapped']
# [10, 'Life Goes On']
# [11, "Hit 'Em Up - Single Version"]
# [12, "Troublesome '96"]
# [13, "Brenda's Got A Baby"]
# [14, "I Ain't Mad At Cha"]
# [15, 'I Get Around']
# [16, 'Changes']
# [17, 'California Love - Original Version']
# [18, "Picture Me Rollin'"]
# [19, 'How Long Will They Mourn Me?']
# [20, 'Toss It Up']
# [21, 'Dear Mama']
# [22, 'All About U']
# [23, 'To Live & Die In L.A.']
# [24, 'Heartz Of Men']
# Meet The Beatles!
# The Beatles
# [0, 'Little Child']
# [1, "I'll Get You"]
# [2, "She's A Woman"]
# [3, "You Can't Do That"]
# [4, 'Day Tripper']
# [5, 'Back In The Ussr']
# [6, 'We Can Work It Out']
# [7, 'I Wanna Be Your Man']
# [8, "Sgt Pepper's Lonely Hearts Club Band"]
# [9, 'Birthday']
# [10, 'I Saw Her Standing There']
# [11, 'Get Back']
# [12, "I'm Down"]
# [13, 'Hey Jude']
# [14, 'Dirty Water']
# [15, 'Jeannie, Jeannie, Jeannie']
# [16, "Tell Me What's Wrong"]
# The Birth of Soul
# Ray Charles
# [0, "The Sun's Gonna Shine Again"]
# [1, 'Roll With My Baby']
# [2, 'The Midnight Hour']
# [3, "Jumpin' In The Morning"]
# [4, 'It Should Have Been Me']
# [5, 'Losing Hand']
# [6, 'Heartbreaker']
# [7, "Sinner's Prayer"]
# [8, 'Mess Around']
# [9, 'Funny But I Still Love You']
# [10, "Feelin' Sad"]
# [11, 'I Wonder Who']
# [12, "Don't You Know - Single/"]
# [13, 'Nobody Cares']
# [14, "Ray's Blues"]
# [15, 'Mr. Charles Blues']
# [16, 'Blackjack - Single/']
# [17, "I've Got A Woman"]
# [18, 'Greenbacks']
# [19, 'Come Back Baby']
# [20, 'A Fool For You']
# [21, 'This Little Girl Of Mine']
# [22, 'Hard Times (No One Knows Better Than I) (R&B)']
# [23, 'A Bit Of Soul']
# [24, 'Mary Ann']
# [25, 'Drown In My Own Tears']
# [26, 'Hallelujah I Love Her So']
# [27, 'What Would I Do Without You']
# [28, 'Lonely Avenue']
# [29, 'I Want To Know']
# [30, 'Leave My Woman Alone']
# [31, "It's Alright"]
# [32, "Ain't That Love"]
# [33, 'Get On The Right Track']
# [34, 'Rockhouse Parts 1 & 2']
# [35, "Swanee River Rock (Talkin' 'Bout That River)"]
# [36, "That's Enough"]
# [37, "Talkin' About You"]
# [38, 'What Kind Of Man Are You']
# [39, 'I Want A Little Girl']
# [40, 'Yes Indeed']
# [41, 'I Had A Dream']
# [42, 'You Be My Baby']
# [43, 'Tell All The World About You']
# [44, 'My Bonnie']
# [45, 'Early In The Morning']
# [46, 'Night Time Is The Right Time']
# [47, "Carryin' That Load"]
# [48, 'Tell Me How Do You Feel']
# [49, "What'd I Say, Pt. I & II"]
# Electric Ladyland
# The Jimi Hendrix Experience
# [0, '...And the Gods Made Love']
# [1, 'Have You Ever Been (To Electric Ladyland)']
# [2, 'Crosstown Traffic']
# [3, 'Voodoo Chile']
# [4, 'Little Miss Strange']
# [5, 'Long Hot Summer Night']
# [6, 'Come On (Let the Good Times Roll)']
# [7, 'Gypsy Eyes']
# [8, 'Burning of the Midnight Lamp']
# [9, 'Rainy Day, Dream Away']
# [10, '1983...(A Merman I Should Turn to Be)']
# [11, 'Moon, Turn the Tides...Gently Gently Away']
# [12, 'Still Raining, Still Dreaming']
# [13, 'House Burning Down']
# [14, 'All Along the Watchtower']
# [15, 'Voodoo Child (Slight Return)']
# Elvis Presley
# Elvis Presley
# [0, 'Heartbreak Hotel']
# [1, "Don't Be Cruel"]
# [2, 'Hound Dog']
# [3, 'Love Me Tender']
# [4, 'Too Much']
# [5, 'All Shook Up']
# [6, '(Let Me Be Your) Teddy Bear']
# [7, 'Jailhouse Rock']
# [8, "Don't"]
# [9, 'Hard Headed Woman - From the Hal Wallis Production "King Creole", a Paramount Picture']
# [10, 'One Night']
# [11, "(Now and Then There's) A Fool Such as I"]
# [12, "A Big Hunk O' Love"]
# [13, 'Stuck On You']
# [14, "It's Now or Never"]
# [15, 'Are You Lonesome Tonight? - Remastered']
# [16, 'Wooden Heart']
# [17, 'Surrender']
# [18, "(Marie's The Name) His Latest Flame"]
# [19, "Can't Help Falling In Love"]
# [20, 'Good Luck Charm']
# [21, "She's Not You - Remastered"]
# [22, 'Return to Sender']
# [23, "(You're The) Devil in Disguise"]
# [24, 'Crying In the Chapel']
# [25, 'In the Ghetto']
# [26, 'Suspicious Minds']
# [27, 'The Wonder of You - Live']
# [28, 'Burning Love']
# [29, 'Way Down']
# [30, 'A Little Less Conversation - JXL Radio Edit Remix']
# Songs in the Key of Life
# Stevie Wonder
# [0, "Love's In Need Of Love Today"]
# [1, 'Have A Talk With God']
# [2, 'Village Ghetto Land']
# [3, 'Contusion']
# [4, 'Sir Duke']
# [5, 'I Wish']
# [6, 'Knocks Me Off My Feet']
# [7, 'Pastime Paradise']
# [8, 'Summer Soft']
# [9, 'Ordinary Pain']
# [10, "Isn't She Lovely"]
# [11, 'Joy Inside My Tears']
# [12, 'Black Man']
# [13, 'Ngiculela-Es Una Historia-I Am Singing']
# [14, "If It's Magic"]
# [15, 'As']
# [16, 'Another Star']
# [17, 'Saturn']
# [18, 'Ebony Eyes']
# [19, 'All Day Sucker']
# [20, "Easy Goin' Evening (My Mama's Call)"]
# Beggars Banquet
# The Rolling Stones
# [0, 'Sympathy For The Devil']
# [1, 'No Expectations']
# [2, 'Dear Doctor']
# [3, 'Parachute Woman']
# [4, 'Jig-Saw Puzzle']
# [5, 'Street Fighting Man']
# [6, 'Prodigal Son']
# [7, 'Stray Cat Blues']
# [8, 'Factory Girl']
# [9, 'Salt Of The Earth']
# Chronicle: The 20 Greatest Hits
# Creedence Clearwater Revival
# [0, "Who's Making Love"]
# [1, 'Take Care Of Your Homework']
# [2, 'Testify (I Wonna)']
# [3, 'I Could Never Be President']
# [4, 'Love Bones']
# [5, 'Steal Away']
# [6, 'I Am Somebody, Part 1']
# [7, "Jody's Got Your Girl And Gone"]
# [8, "I Don't Wanna Lose You"]
# [9, "Hijackin' Love"]
# [10, 'Standing In For Jody']
# [11, 'Doing My Own Thing - Part 1']
# [12, "Stop Doggin' Me"]
# [13, 'I Believe In You (You Believe In Me)']
# [14, 'Cheaper To Keep Her']
# [15, "We're Getting Careless With Our Love"]
# [16, "I've Been Born Again"]
# [17, "It's September"]
# [18, 'Try Me Tonight']
# [19, "Just Keep On Lovin' Me"]
# Greatest Hits
# Sly & The Family Stone
# [0, 'Keep Ya Head Up']
# [1, '2 Of Amerikaz Most Wanted']
# [2, 'Temptations']
# [3, 'God Bless The Dead - 1998 Greatest Hits']
# [4, 'Hail Mary']
# [5, 'Me Against The World']
# [6, 'How Do U Want It']
# [7, 'So Many Tears']
# [8, 'Unconditional Love']
# [9, 'Trapped']
# [10, 'Life Goes On']
# [11, "Hit 'Em Up - Single Version"]
# [12, "Troublesome '96"]
# [13, "Brenda's Got A Baby"]
# [14, "I Ain't Mad At Cha"]
# [15, 'I Get Around']
# [16, 'Changes']
# [17, 'California Love - Original Version']
# [18, "Picture Me Rollin'"]
# [19, 'How Long Will They Mourn Me?']
# [20, 'Toss It Up']
# [21, 'Dear Mama']
# [22, 'All About U']
# [23, 'To Live & Die In L.A.']
# [24, 'Heartz Of Men']
# Appetite for Destruction
# Guns N' Roses
# [0, 'Welcome To The Jungle']
# [1, "It's So Easy"]
# [2, 'Nightrain']
# [3, 'Out Ta Get Me']
# [4, 'Mr. Brownstone']
# [5, 'Paradise City']
# [6, 'My Michelle']
# [7, 'Think About You']
# [8, "Sweet Child O' Mine"]
# [9, "You're Crazy"]
# [10, 'Anything Goes']
# [11, 'Rocket Queen']
# Achtung Baby
# U2
# [0, 'Zoo Station']
# [1, 'Even Better Than The Real Thing']
# [2, 'One']
# [3, 'Until The End Of The World']
# [4, "Who's Gonna Ride Your Wild Horses"]
# [5, 'So Cruel']
# [6, 'The Fly']
# [7, 'Mysterious Ways']
# [8, "Tryin' To Throw Your Arms Around The World"]
# [9, 'Ultra Violet (Light My Way)']
# [10, 'Acrobat']
# [11, 'Love Is Blindness']
# [12, 'Lady With The Spinning Head (UV1)']
# [13, 'Blow Your House Down']
# [14, 'Salomé']
# [15, 'Even Better Than The Real Thing - Single Version']
# [16, 'Satellite Of Love']
# [17, "Who's Gonna Ride Your Wild Horses - Temple Bar Remix"]
# [18, 'Paint It Black']
# [19, 'Even Better Than The Real Thing - Fish Out Of Water Remix']
# [20, 'Mysterious Ways - The Perfecto Mix']
# [21, 'Night And Day - Steel String Remix']
# [22, 'The Lounge Fly Mix']
# [23, 'Fortunate Son']
# [24, 'Alex Descends Into Hell For A Bottle Of Milk / Korova 1']
# [25, 'Where Did It All Go Wrong?']
# Sticky Fingers
# The Rolling Stones
# [0, 'Brown Sugar']
# [1, 'Sway - Remastered']
# [2, 'Wild Horses']
# [3, "Can't You Hear Me Knocking - Remastered"]
# [4, 'You Gotta Move - Remastered']
# [5, 'Bitch']
# [6, 'I Got The Blues - Remastered']
# [7, 'Sister Morphine - Remastered']
# [8, 'Dead Flowers - Remastered']
# [9, 'Moonlight Mile - Remastered']
# Back to Mono
# Phil Spector
# [0, 'Back To Mono']
# Moondance
# Van Morrison
# [0, 'And It Stoned Me']
# [1, 'Moondance']
# [2, 'Crazy Love']
# [3, 'Caravan']
# [4, 'Into The Mystic']
# [5, 'Come Running']
# [6, 'These Dreams Of You']
# [7, 'Brand New Day']
# [8, 'Everyone']
# [9, 'Glad Tidings']
# Kid A
# Radiohead
# [0, 'Everything In Its Right Place']
# [1, 'Kid A']
# [2, 'The National Anthem']
# [3, 'How To Disappear Completely']
# [4, 'Treefingers']
# [5, 'Optimistic']
# [6, 'In Limbo']
# [7, 'Idioteque']
# [8, 'Morning Bell']
# [9, 'Motion Picture Soundtrack']
# [10, 'Untitled']
# Off the Wall
# Michael Jackson
# [0, "Don't Stop 'Til You Get Enough - Single Version"]
# [1, 'Rock with You - Single Version']
# [2, "Workin' Day and Night"]
# [3, 'Get on the Floor']
# [4, 'Off the Wall']
# [5, 'Girlfriend']
# [6, "She's Out of My Life - Single Version"]
# [7, "I Can't Help It"]
# [8, "It's the Falling in Love"]
# [9, 'Burn This Disco Out']
# [Led Zeppelin IV]
# Led Zeppelin
# [0, 'Black Dog']
# [1, 'Rock And Roll']
# [2, 'The Battle Of Evermore']
# [3, 'Stairway To Heaven']
# [4, 'Misty Mountain Hop']
# [5, 'Four Sticks']
# [6, 'Going To California']
# [7, 'When The Levee Breaks']
# [8, 'Black Dog - Basic Track With Guitar Overdubs']
# [9, 'Rock And Roll - Alternate Mix']
# [10, 'The Battle Of Evermore - Mandolin / Guitar Mix From Headley Grange']
# [11, 'Stairway To Heaven - Sunset Sound Mix']
# [12, 'Misty Mountain Hop - Alternate Mix']
# [13, 'Four Sticks - Alternate Mix']
# [14, 'Going To California - Mandolin / Guitar Mix']
# [15, 'When The Levee Breaks - Alternate UK Mix In Progress']
# The Stranger
# Billy Joel
# [0, "Movin' Out (Anthony's Song)"]
# [1, 'The Stranger']
# [2, 'Just the Way You Are']
# [3, 'Scenes from an Italian Restaurant']
# [4, 'Vienna']
# [5, 'Only the Good Die Young']
# [6, "She's Always a Woman"]
# [7, 'Get It Right the First Time']
# [8, 'Everybody Has a Dream']
# [9, 'Miami 2017 (Seen the Lights Go Out On Broadway) - Live June 1977 At Carnegie Hall, New York, NY']
# [10, 'Prelude / Angry Young Man - Live June 1977 At Carnegie Hall, New York, NY']
# [11, 'New York State of Mind - Live June 1977 At Carnegie Hall, New York, NY']
# [12, 'Just the Way You Are - Live June 1977 At Carnegie Hall, New York, NY']
# [13, "She's Got a Way - Live June 1977 At Carnegie Hall, New York, NY"]
# [14, 'The Entertainer - Live June 1977 At Carnegie Hall, New York, NY']
# [15, 'Scenes from an Italian Restaurant - Live June 1977 At Carnegie Hall, New York, NY']
# [16, 'Band Introductions - Live June 1977 At Carnegie Hall, New York, NY']
# [17, 'Captain Jack - Live June 1977 At Carnegie Hall, New York, NY']
# ...
# [37, 'Long-Forgotten Fairytale']
# [38, 'Kiss Me Like You Mean It']
# [39, 'Papa Was a Rodeo']
# [40, 'Epitaph for My Heart']
# [41, 'Asleep and Dreaming']
# [42, 'The Sun Goes Down and the World Goes Dancing']
# [43, 'The Way You Say Good-Night']
# [44, 'Abigail, Belle of Kilronan']
# [45, 'I Shatter']
# [46, 'Underwear']
# [47, "It's a Crime"]
# [48, 'Busby Berkeley Dreams']
# [49, "I'm Sorry I Love You"]
# A Rush of Blood to the Head
# Coldplay
# [0, 'Politik']
# [1, 'In My Place']
# [2, 'God Put A Smile Upon Your Face']
# [3, 'The Scientist']
# [4, 'Clocks']
# [5, 'Daylight']
# [6, 'Green Eyes']
# [7, 'Warning Sign']
# [8, 'A Whisper']
# [9, 'A Rush Of Blood To The Head']
# [10, 'Amsterdam']
# Tunnel of Love
# Bruce Springsteen
# [0, "Ain't Got You"]
# [1, 'Tougher Than the Rest']
# [2, 'All That Heaven Will Allow']
# [3, 'Spare Parts']
# [4, 'Cautious Man']
# [5, 'Walk Like A Man']
# [6, 'Tunnel of Love']
# [7, 'Two Faces']
# [8, 'Brilliant Disguise']
# [9, 'One Step Up']
# [10, "When You're Alone"]
# [11, "Valentine's Day"]
# The Paul Butterfield Blues Band
# The Paul Butterfield Blues Band
# [0, 'Born In Chicago']
# [1, 'Shake Your Money-Maker']
# [2, 'Blues With A Feeling']
# [3, 'Thank You Mr. Poobah']
# [4, 'I Got My Mojo Working']
# [5, 'Mellow Down Easy']
# [6, "Screamin'"]
# [7, 'Our Love Is Drifting']
# [8, 'Mystery Train']
# [9, 'Last Night']
# [10, 'Look Over Yonders Wall']
# The Score
# Fugees
# [0, 'Red Intro']
# [1, 'How Many Mics']
# [2, 'Ready or Not']
# [3, 'Zealots']
# [4, 'The Beast']
# [5, 'Fu-Gee-La']
# [6, 'Family Business']
# [43, "Waitin' For A Train"]
# [44, "Jimmie Rodgers' Last Blue Yodel (The Women Make A Fool Out Of Me)"]
# [45, 'California Cottonfields']
# [46, 'White Line Fever - Down Every Road Version']
# [47, "Workin' Man Blues"]
# [48, 'Okie From Muskogee - Down Every Road Version']
# [49, "I Can't Stop Loving You - Live"]
# All Time Greatest Hits
# Loretta Lynn
# [0, 'I Got You (I Feel Good)']
# [1, 'Get Up (I Feel Like Being A) Sex Machine - Pt. 1 & 2']
# [2, "I Got The Feelin'"]
# [3, 'Mother Popcorn - Single Version']
# [4, 'Give It Up Or Turnit A Loose']
# [5, 'Make It Funky']
# [6, "Papa's Got A Brand New Bag"]
# [7, 'Think']
# [8, "It's A Man's, Man's, Man's World"]
# [9, 'Try Me']
# [10, 'Night Train - Single Version']
# [11, 'Cold Sweat']
# [12, 'Get On The Good Foot']
# [13, "Papa Don't Take No Mess"]
# [14, 'The Payback']
# [15, "Say It Loud - I'm Black And I'm Proud"]
# [16, 'Super Bad']
# [17, 'Hot Pants (She Got To Use What She Got To Get What She Wants)']
# [18, 'Get Up Offa That Thing']
# [19, 'Please, Please, Please']
# Maggot Brain
# Funkadelic
# [0, 'Maggot Brain']
# [1, 'Can You Get To That']
# [2, 'Hit It and Quit It']
# [3, 'You and Your Folks, Me and My Folks']
# [4, 'Super Stupid']
# [5, 'Back In Our Minds']
# [6, 'Wars of Armageddon']
# [7, 'Whole Lot of BS - 1972 Version']
# [8, 'I Miss My Baby - 1972 Version']
# [9, 'Maggot Brain - Alternate Mix']
# Only Built 4 Cuban Linx
# Raekwon
# [0, 'Striving For Perfection']
# [1, 'Knuckleheadz']
# [2, 'Knowledge God']
# [3, 'Criminology']
# [4, 'Incarcerated Scarfaces']
# [5, 'Rainy Dayz']
# [6, 'Guillotine (Swordz)']
# [7, 'Can It Be All So Simple (Remix)']
# [8, 'Shark Niggas (Biters)']
# [9, 'Ice Water']
# [10, 'Glaciers of Ice']
# [11, 'Verbal Intercourse']
# [12, 'Wisdom Body']
# [13, 'Spot Rusherz']
# [14, 'Ice Cream']
# [15, 'Wu-Gambinos - Hidden Chambers Remix']
# [16, 'Heaven & Hell']
# [17, 'North Star (Jewels)']
# Voodoo
# D'Angelo
# [0, 'Playa Playa']
# [1, "Devil's Pie"]
# [2, 'Left And Right']
# [3, 'The Line']
# [4, 'Send It On']
# [5, 'Chicken Grease']
# [6, "One Mo'Gin"]
# [7, 'The Root']
# [8, 'Spanish Joint']
# [9, "Feel Like Makin' Love"]
# [10, "Greatdayndamornin'/Booty"]
# [11, 'Untitled (How Does It Feel)']
# [12, 'Africa']
# Guitar Town
# Steve Earle
# [0, 'Guitar Town']
# [1, "Goodbye's All We've Got Left"]
# [2, 'Hillbilly Highway']
# [3, "Good Ol' Boy (Gettin' Tough)"]
# [4, 'My Old Friend The Blues']
# [5, 'Someday']
# [6, 'Think It Over']
# [7, 'Fearless Heart']
# [8, "Little Rock 'N' Roller"]
# [9, 'Down The Road']
# Entertainment!
# Gang of Four
# [0, '11:11']
# [1, 'Blonde']
# [2, 'Peach (Lobotomy)']
# [3, 'We Need to Talk']
# [4, 'Not Warriors']
# [5, 'Lucky People']
# [6, 'Rare']
# [7, 'TANTRUM']
# [8, 'Crybaby']
# [9, 'Sleep Alone']
# All the Young Dudes
# Mott the Hoople
# [0, 'Sweet Jane']
# [1, "Momma's Little Jewel"]
# [2, 'All the Young Dudes']
# [3, 'Sucker']
# [4, "Jerkin' Crocus"]
# [5, 'One of the Boys']
# [6, 'Soft Ground']
# [7, 'Ready for Love / After Lights']
# [8, 'Sea Diver']
# [9, 'One of the Boys - Demo Version']
# [10, 'Black Scorpio - Demo Version']
# [11, 'Ride On The Sun - Demo Version']
# [12, 'One of the Boys - Single Verison']
# [13, 'All the Young Dudes']
# [14, 'Sucker - Live Version']
# [15, 'Sweet Jane - Live Version']
# Vitalogy
# Pearl Jam
# [0, 'Last Exit - Remastered']
# [1, 'Spin the Black Circle - Remastered']
# [2, 'Not for You - Remastered']
# [3, 'Tremor Christ - Remastered']
# [4, 'Nothingman - Remastered']
# [5, 'Whipping - Remastered']
# [6, 'Pry, To - Remastered']
# [7, 'Corduroy - Remastered']
# [8, 'Bugs - Remastered']
# [9, "Satan's Bed - Remastered"]
# [10, 'Better Man - Remastered']
# [11, 'Aya Davanita - Remastered']
# [12, 'Immortality - Remastered']
# [13, 'Stupidmop - Remastered']
# [14, 'Better Man - Guitar / Organ Only']
# [15, 'Corduroy - Alternate Take']
# [16, 'Nothingman - Demo']
# That's the Way of the World
# Earth, Wind & Fire
# [0, 'Shining Star']
# [1, "That's the Way of the World"]
# [2, "Happy Feelin'"]
# [3, 'All About Love']
# [4, "Yearnin' Learnin'"]
# [5, 'Reasons']
# [6, 'Africano']
# [7, 'See the Light']
# She's So Unusual
# Cyndi Lauper
# [0, 'Money Changes Everything']
# [1, 'Girls Just Want to Have Fun']
# [2, 'When You Were Mine']
# [3, 'Time After Time']
# [4, 'She Bop']
# [5, 'All Through the Night']
# [6, 'Witness']
# [7, "I'll Kiss You"]
# [8, "He's so Unusual"]
# [9, 'Yeah Yeah']
# New Day Rising
# Husker Du
# [0, 'New Day Rising']
# [1, 'The Girl Who Lives On Heaven Hill']
# [2, 'I Apologize']
# [3, 'Folk Lore']
# [4, 'If I Told You']
# [5, 'Celebrated Summer']
# [6, 'Perfect Example']
# [7, 'Terms Of Psychic Warfare']
# [8, '59 Times The Pain']
# [9, 'Powerline']
# [10, 'Books About UFOs']
# [11, "I Don't Know What You're Talking About"]
# [12, 'How To Skin A Cat']
# [13, "Whatcha Drinkin'"]
# [14, 'Plans I Make']
# Destroyer
# KISS
# [0, 'Detroit Rock City']
# [1, 'King Of The Night Time World']
# [2, 'God Of Thunder']
# [3, 'Great Expectations']
# [4, 'Flaming Youth']
# [5, 'Sweet Pain']
# [6, 'Shout It Out Loud']
# [7, 'Beth']
# [8, 'Do You Love Me']
# [9, 'Rock And Roll Party']
# Tres hombres
# ZZ Top
# [0, "Waitin' for the Bus - 2006 Remastered Version"]
# [1, 'Jesus Just Left Chicago - 2006 Remastered Version']
# [2, 'Beer Drinkers & Hell Raisers - 2006 Remastered Version']
# [3, 'Master of Sparks - 2006 Remastered Version']
# [4, 'Hot, Blue and Righteous - 2006 Remastered Version']
# [5, 'Move Me On Down The Line - Remastered Version']
# [6, 'Precious And Grace - Remastered Version']
# [7, 'La Grange - 2005 Remastered Version']
# [8, 'Sheik - Remastered Version']
# [9, 'Have You Heard ? - Remastered Version']
# [10, "Waitin' For The Bus - Live Version Previously Unissued"]
# [11, 'Jesus Just Left Chicago - Live Version Previously Unissued']
# [12, 'La Grange - Live Version Previously Unissued']
# Born Under a Bad Sign
# Albert King
# [0, 'Born Under A Bad Sign']
# [1, 'Crosscut Saw']
# [2, 'Kansas City']
# [3, "Oh, Pretty Woman - Can't Make You Love Me"]
# [4, "Down Don't Bother Me"]
# [5, 'The Hunter']
# [6, 'I Almost Lost My Mind']
# [7, 'Personal Manager']
# [8, 'Laundromat Blues']
# [9, 'As The Years Go Passing By']
# [10, 'The Very Thought Of You']
# Touch
# Eurythmics
# [0, 'Everytime We Touch']
# [1, 'Everytime We Touch - Rocco vs. Bass-T Remix']
# [2, 'Everytime We Touch - Dan Winter Edit']
# [3, 'Everytime We Touch - Verano Edit']
# [4, 'Everytime We Touch - Original Mix']
# [5, 'Everytime We Touch - Rocco vs. Bass-T Remix']
# [6, 'Everytime We Touch - Dan Winter Remix']
# [7, 'Everytime We Touch - Scarf! Remix']
# [8, 'Everytime We Touch - Verano Remix']
# Yankee Hotel Foxtrot
# Wilco
# [0, 'I am trying to break your heart']
# [1, 'Kamera']
# [2, 'Radio cure']
# [3, 'War on war']
# [4, 'Jesus, etc.']
# [5, 'Ashes of American Flags']
# [6, 'Heavy metal drummer']
# [7, "I'm the man who loves you"]
# [8, 'Pot kettle black']
# [9, 'Poor places']
# [10, 'Reservations']
# Oracular Spectacular
# MGMT
# [0, 'Time to Pretend']
# [1, 'Weekend Wars']
# [2, 'The Youth']
# [3, 'Electric Feel']
# [4, 'Kids']
# [5, '4th Dimensional Transition']
# [6, 'Pieces of What']
# [7, 'Of Moons, Birds & Monsters']
# [8, 'The Handshake']
# [9, 'Future Reflections']
# Give It Up
# Bonnie Raitt
# [0, 'Give It Up']
# Boz Scaggs
# Boz Scaggs
# [0, "Runnin' Blue"]
# [1, 'We Were Always Sweethearts']
# [2, 'Near You']
# [3, 'Painted Bells']
# [4, 'Dinah Flo']
# [5, 'Might Have to Cry']
# [6, 'You Make It So Hard (To Say No)']
# [7, 'I Got Your Number']
# [8, 'Slow Dancer']
# [9, 'Hercules']
# [10, 'What Can I Say']
# [11, "It's Over"]
# [12, 'Harbor Lights']
# [13, 'Lowdown']
# [14, 'Lido Shuffle']
# [15, "We're All Alone"]
# [16, 'Loan Me A Dime']
# [17, 'Hard Times']
# [18, '1993']
# [19, 'JoJo']
# [20, "Isn't It Time"]
# [21, 'Simone']
# [22, 'Breakdown Dead Ahead']
# [23, 'Miss Sun']
# [24, "Look What You've Done to Me"]
# [25, 'Heart of Mine']
# [26, "What's Number One?"]
# [27, 'Drowning In the Sea of Love - Live']
# [28, 'Sierra']
# [29, 'Some Change']
# [30, 'As the Years Go Passing By - Live']
# [31, 'Just Go']
# [32, 'Goodnight Louise']
# White Blood Cells
# The White Stripes
# [0, 'Dead Leaves And The Dirty Ground']
# [1, 'Hotel Yorba']
# [2, "I'm Finding It Harder To Be A Gentleman"]
# [3, 'Fell In Love With A Girl']
# [4, 'Expecting']
# [5, 'Little Room']
# [6, 'The Union Forever']
# [7, "The Same Boy You've Always Known"]
# [8, "We're Going To Be Friends"]
# [9, 'Offend In Every Way']
# [10, 'I Think I Smell A Rat']
# [11, 'Aluminum']
# [12, "I Can't Wait"]
# [13, 'Now Mary']
# [14, 'I Can Learn']
# [15, 'This Protector']
# The Stone Roses
# The Stone Roses
# [0, 'I Wanna Be Adored - Remastered']
# [1, 'She Bangs the Drums - Remastered']
# [2, 'Waterfall - Remastered']
# [3, "Don't Stop - Remastered"]
# [4, 'Bye Bye Bad Man - Remastered']
# [5, 'Elizabeth My Dear - Remastered']
# [6, '(Song for My) Sugar Spun Sister - Remastered']
# [7, 'Made of Stone - Remastered']
# [8, 'Shoot You Down - Remastered']
# [9, 'This Is the One - Remastered']
# [10, 'I Am the Resurrection - Remastered']
# [11, 'Fools Gold - Remastered']
# Live in Cook County Jail
# B.B. King
# [0, 'Introduction']
# [1, 'Every Day I Have The Blues']
# [2, 'How Blue Can You Get?']
# [3, 'Worry, Worry, Worry']
# [4, "Medley: 3 O'Clock Blues/Darlin' You Know I Love You"]
# [5, 'Sweet Sixteen']
# [6, 'The Thrill Is Gone']
# [7, 'Please Accept My Love']
# Aquemini
# OutKast
# [0, 'Hold On Be Strong']
# [1, 'Return of the "G"']
# [2, 'Rosa Parks']
# [3, 'Skew It on the Bar-B']
# [4, 'Aquemini']
# [5, 'Synthesizer']
# [6, 'Slump']
# [7, 'West Savannah']
# [8, "Da Art of Storytellin' (Pt. 1)"]
# [9, "Da Art of Storytellin' (Pt. 2)"]
# [10, 'Mamacita']
# [11, 'SpottieOttieDopaliscious']
# [12, "Y'All Scared"]
# [13, 'Nathaniel']
# [14, 'Liberation']
# [15, 'Chonkyfire']

# %%
​
​
#Begin Functions V1
​
def find_by_name(name):
    for album in albums:
        if album['album'] == name:
            return album
​
​
def find_by_rank(rank):
    for album in albums:
        if int(album['number']) == rank:
            return album
​
def find_by_year(year):
    all_albums_in_year = []
    for album in albums:
        if int(album['year']) == year:
            all_albums_in_year.append(album)
    return all_albums_in_year
​
def find_by_years(start_year, end_year):
    all_albums_within_years = []
    for album in albums:
        if int(album['year']) >= start_year and int(album['year']) <= end_year:
            all_albums_within_years.append(album)
    return all_albums_within_years
​
def find_by_ranks(start_rank, end_rank):
    all_albums_within_ranks = []
    for album in albums:
        if int(album['number']) >= start_rank and int(album['number']) <= end_rank:
            all_albums_within_ranks.append(album)
    return all_albums_within_ranks
​
def all_titles():
    every_album_title = []
    for album in albums:
        every_album_title.append(album['album'])
    return every_album_title
​
def all_artists():
    every_album_artist = []
    for album in albums:
        every_album_artist.append(album['artist'])
    return every_album_artist
​
def most_albums():
    every_artist = list(all_artists())
    unique_artists = set(all_artists())
    artists_counts = []
    raw_counts = []
    most_artists = []
    for artist in unique_artists:
        count = all_artists().count(artist)
        artists_counts.append([artist, count])
        raw_counts.append(count)
    most = max(raw_counts)
    for artist_count in artists_counts:
        if most == artist_count[1]:
            most_artists.append(str(artist_count[0]+ " - " + str(artist_count[1])))
    return most_artists
​
def genre_list():
    genre_list = []
    for album in albums:
        raw_genre = album["genre"]
        split = raw_genre.replace("& ", "").split(", ")
        genre_list.extend(split)
#         genre_list.append(album["genre"])
        
    return genre_list
​
def all_years():
    every_album_year = []
    for album in albums:
        every_album_year.append(int(album['year']))
    return every_album_year
def all_decades():
    all_years_list = list(all_years())
    every_album_decade = []
    for year in all_years_list:
        every_album_decade.append(year - year % 10)
    return every_album_decade
def hist_of_albums_by_decade():
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    list_bins = sorted(list(set(all_decades())))
    years_list = all_years()
    plt.hist(years_list, bins = list_bins)
    
    plt.xlabel('Decades')
    plt.ylabel('Frequency of Decades')
    plt.title('Number of Albums released by Decade')
    plt.show()
​
# Set plot space as inline for inline plots and qt for external plots
# %matplotlib inline
​
def genre_counts():
    genre_list = []
    genre_counts = []
    for album in albums:
        raw_genre = album["genre"]
        split = raw_genre.replace("& ", "").replace(", ", ",").split(",")
        genre_list.extend(split)
    unique_genres = list(set(genre_list))
    sorted_genres = sorted(unique_genres)
    for genre in sorted_genres:
        genre_counts.append(genre_list.count(genre))
    return [sorted_genres, genre_counts]
genre_counts()
​
# Use the bar() function to create a plot using the above values of x and y. Add a label.
def genre_bar_graph():
    plt.figure(figsize=(14,6))
    plt.bar(genre_counts()[0], genre_counts()[1], label='Genre Counts')
    plt.xlabel('Genres')
    plt.ylabel('Counts')
    plt.title('Genre Counts')
    plt.legend()
    # Output the final plot
    plt.show()
    
​
#Revised Functions
def find_by_individual_value(file, key, value):
    all_values = []
    for f in file:
        if f[key] == value:
            return f
        
def find_by_year(file, year):
    all_in_year = []
    for f in file:
        if int(f['year']) == year:
            all_in_year.append(f)
    return all_in_year
​
def find_by_years(file, start_year, end_year):
    all_within_years = []
    for f in file:
        if int(f['year']) >= start_year and int(f['year']) <= end_year:
            all_within_years.append(f)
    return all_within_years
​
def find_by_ranks(file, start_rank, end_rank):
    all_within_ranks = []
    for f in file:
        if int(f['rank']) >= start_rank and int(f['rank']) <= end_rank:
            all_within_ranks.append(f)
    return all_within_ranks
​
find_by_ranks(songs, 1,20)
​
#This be experimental
​
def album_top_songs():
    top_songs_list = []
    top_song_count = []
    for song in songs:
        top_songs_list.append(song['name'])

    for disc in discography:
        song_list = disc["tracks"]
        count = 0
        for song in disc:
            if song.replace(' - Remastered', '') in top_songs_list:
                count += 1
        top_song_count.append([disc["album"], count])
    return top_song_count
    
def songs_on_top_albums():
    songs_on_top_albums = []
    album_titles = all_titles()
    for album_title in album_titles:
        for disc in discography:
            if album_title == disc['album']:
                songs_on_top_albums.append(disc['tracks'])
            else:
                songs_on_top_albums.append('Nada')
    return album_titles
​
songs_on_top_albums()
# Out:
#   File "<ipython-input-2-3556b6453a7e>", line 4
#     ​
#     ^
# SyntaxError: invalid character in identifier
